# %%
setwd("/home/josephusset@vhio.org/biomarkers/5_combine_markers/")

# %%
source(paste0(dirname(getwd()),'/map.r'))
source(paste0(HELP_DIR, "shortcuts.r"))

# %% [markdown]
# ### 0 - Read and combined prepared datasets

# %%
setwd(READY_DIR)

# %%
sources <- 
c("clinical", 
  "purity", 
  "drivers", 
  "cn_simple",
  "isofox_genesets",
  "cider_dna", 
  "teal", 
  "viral", 
  "lilac", 
  "neo", 
  "neo_pep", 
  "svs", 
  "gie", 
  "fusions_dna", 
  "chord")

# %%
dfs <- list()
system.time(
for( i in sources){
  print(i); flush.console()
  dfs[[i]] <- fread( paste0(i, "_ready.csv"))
})

# %%
ready <- dfs %>% reduce(left_join, by = "sampleId")

# %% [markdown]
# ### 1 - Small cleaning

# %% [markdown]
# - Driver and Viral should have 0's for NAs (indicate no events)

# %%
ready <- ready %>% mutate( across(c(contains("driver"), contains("viral")), ~replace_na(.,0) ))

# %% [markdown]
# ### 2 - Save combined dataset

# %%
fwrite( ready, paste0(SHARE_DIR, "biomarkers_base.csv") )
