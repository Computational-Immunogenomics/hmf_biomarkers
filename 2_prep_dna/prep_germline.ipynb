# %%
source(paste0(dirname(getwd()),'/map.r'))
source(paste0(HELP_DIR, "shortcuts.r"))

# %% [markdown]
# ### 0 - Explore

# %%
germline <- 
fread(paste0(I_DIR, "germline/germline.csv")) %>% 
 fi(!canonicalCodingEffect %in% c("SYNONYMOUS", "NONE", ""))

# %%
germline %>% 
 gb(gene, chromosome, position) %>% 
 su(ct = n()) %>% 
 ar(desc(ct)) %>% 
 gb(gene) %>% 
 mu(tot = sum(ct))

# %% [markdown]
# ### 1 - Write output
