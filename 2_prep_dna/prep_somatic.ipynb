# %%
source(paste0(dirname(getwd()),'/map.r'))
source(paste0(HELP_DIR, "shortcuts.r"))

# %% [markdown]
# #### 0 - Read somatic exome and RNA VAF
# - RNA Vafs

# %%
rna_vaf <- fread(paste0(TMP_DIR, "rna_vaf.csv"))

# %% [markdown]
# - Directory with whole somatic exome output

# %%
EXOME_DIR <- paste0(TMP_DIR, "somatic_exome_big/")

# %% [markdown]
# - Remove non-translated reads (make much smaller, and easier to work with)

# %%
remove <- c("3_prime_UTR_variant","5_prime_UTR_variant","intron_variant","upstream_gene_variant","non_coding_transcript_exon_variant")

# %% [markdown]
# ### 1 - Run the joins

# %%
go <- data.frame()

# %%
for( i in list.files(EXOME_DIR)){
  fp <- paste0(EXOME_DIR, i)
  print(fp); flush.console()
  tmp <- 
  fread( fp ) %>% 
    fi(! annotation %in% remove) %>% 
    lj(rna_vaf, by = c("sampleId", "chromosome", "position", "REF", "ALT", "gene", "transcript"))
  go <- rbind(go, tmp)
}

# %% [markdown]
# ### 2 - Write output

# %%
fwrite(go, paste0(TMP_DIR, "somatic_exome.csv"))

# %%
df <- fread(paste0(TMP_DIR, "drivers.csv"))

# %%
fread("/mnt/bioinfnas2/immunocomp/shared_reference_data/chatGPT_gene_annotation.csv") %>% head(12)

# %%
fread(paste0(TMP_DIR, "drivers.csv")) %>% 
 gb(likelihoodMethod) %>% 
 su(ct = n()) %>% 
 ar(desc(ct))

# %%
fread(paste0(TMP_DIR, "structural_variants/breakend.csv")) %>% 
 fi(disruptive) %>% 
 se(sampleId, svId, gene, disruptive, reportedDisruption, undisruptedCopyNumber) 
 %>% unique()
