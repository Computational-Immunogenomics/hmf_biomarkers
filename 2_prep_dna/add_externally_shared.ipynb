# %%
source(paste0(dirname(getwd()),'/map.r'))
source(paste0(HELP_DIR, "shortcuts.r"))

# %% [markdown]
# ### 0 - Prepare external data from Manuel

# %% [markdown]
# - Could be updated to include more

# %%
smoking <- fread("/mnt/bioinfnas2/immunocomp/manuel/tme/0_organise_data/output_data/aetiology_features/smoker_status.csv.gz")
colibactin <- fread("/mnt/bioinfnas2/immunocomp/manuel/tme/0_organise_data/output_data/aetiology_features/colibactin_status.csv.gz")
mps <- fread("/mnt/bioinfnas2/immunocomp/manuel/tme/metaPrograms/activity/MP_scores_bySample_usingControlSet.txt.gz")
mps_activity <- fread("/mnt/bioinfnas2/immunocomp/manuel/tme/nmf_programs/test_6/analysis/initialNMF_sample_scores/data/NMF_scores_bySample_usingControlSet.txt")

# %% [markdown]
# - Get ready

# %%
smoking_ready <- smoking %>% tm(sampleId, clin_smoker = smoker)

# %%
colibactin_ready <- colibactin %>% rename_with(~ paste0("colibactin_", .), -1)

# %%
mps_ready <- 
metaprograms %>%
 rename(sampleId = sample_id) %>% 
 rename_with(~ paste0("metaprogram_", .), -1)

# %%
mps_activity_ready <- 
mps_activity %>% 
 rename(sampleId = sample_id) %>% 
 rename_with(~ paste0("metaprogram_activity_", .), -1)

# %% [markdown]
# - Together

# %%
external_ready <- 
smoking_ready %>% 
 full_join(colibactin_ready, by = "sampleId") %>% 
 full_join(mps_ready, by = "sampleId") %>% 
 full_join(mps_activity_ready, by = "sampleId")

# %% [markdown]
# ### 1 - Send it

# %%
fwrite(external_ready, paste0(READY_DIR, "external_ready.csv"))
