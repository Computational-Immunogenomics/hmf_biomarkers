# %%
source(paste0(dirname(dirname(dirname(getwd()))),'/map.r'))
source(paste0(HELP_DIR, "shortcuts.r"))
source(paste0(HELP_DIR, "helpers.r"))

# %%
library(corrplot)

# %% [markdown]
# # Read ready biomarkers data

# %%
d <- fread(paste0(SHARE_DIR, "prognostic_base_survival_data.csv"))

# %%
r <- fread(paste0(SHARE_DIR, "prognostic_survival_results.csv"))

# %% [markdown]
# # See

# %%
go <- 
r %>% 
 ar(pval) %>% 
 fi(grepl("rna", x)) %>% 
 fi(grepl("Pan-Cancer", cohort)) %>% 
 fi(pval < 1e-15) %>% 
 pu(x)

# %%
#?corrplot

# %%
corrplot(cor(d %>% se(any_of(go))), order = "hclust", tl.cex = .3)
