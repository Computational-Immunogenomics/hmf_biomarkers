# %%
options(dplyr.summarise.inform = FALSE)
library(tidyverse)
library(data.table)
library(survival)
library(gridExtra)

# %%
source(paste0(dirname(dirname(dirname(getwd()))),'/map.r'))
source(paste0(dirname(dirname(dirname(getwd()))),'/stats.r'))

# %% [markdown]
# #### 0 - Run analyses

# %%
system.time(go <- readRDS(paste0(SHARE_DIR, "ready_ex.Rds")))
# Out:
#    user  system elapsed
#   2.385   0.290   3.560

# %%
df <- go$data_ready
features <- go$features

# %% [markdown]
# #### 1 - Run Survival Analyses

# %% [markdown]
# - Survival, test everything

# %%
system.time(os_results <- scanner("Surv(Y_os_days, Y_os_event)", features, "+ location + clin_age + clin_sex", "df", "coxph"))
# Out:
# Warning message in pchisq(test_stat, df):
# “NaNs produced”
# Warning message in pchisq(test_stat, df):
# “NaNs produced”
# Warning message in pchisq(test_stat, df):
# “NaNs produced”
# Warning message in pchisq(test_stat, df):
# “NaNs produced”
# Warning message in pchisq(test_stat, df):
# “NaNs produced”
# Warning message in pchisq(test_stat, df):
# “NaNs produced”
# Warning message in pchisq(test_stat, df):
# “NaNs produced”
# Warning message in pchisq(test_stat, df):
# “NaNs produced”
# Warning message in pchisq(test_stat, df):
# “NaNs produced”
# Warning message in pchisq(test_stat, df):
# “NaNs produced”
# Warning message in pchisq(test_stat, df):
# “NaNs produced”
# Warning message in pchisq(test_stat, df):
# “NaNs produced”

# %%
get_stats( y = "Surv(Y_os_days, Y_os_event)", 
                        x = i, 
                        covariate = " + clin_primaryTumorLocation2 + clin_age + clin_sex", 
                        data = "df", 
                        model = "coxph")
# Out:
# Error in coxph(formula = Surv(Y_os_days, Y_os_event) ~ viral_MCV + clin_primaryTumorLocation2 + : could not find function "coxph"
# Traceback:
#
# 1. get_stats(y = "Surv(Y_os_days, Y_os_event)", x = i, covariate = " + clin_primaryTumorLocation2 + clin_age + clin_sex",
#  .     data = "df", model = "coxph")
# 2. get_model(y = y, x = x, covariate = covariate, data = data, model = model)
# 3. do.call("coxph", list(formula = formula, data = as.name(data)))

# %%
results <- data.frame()
system.time(
for( i in features){
    results <- 
      rbind(results, 
            get_stats2( y = "Surv(Y_os_days, Y_os_event)", 
                        x = i, 
                        covariate = " + clin_primaryTumorLocation2 + clin_age + clin_sex", 
                        data = "df", 
                        model = "coxph"))
})
# Out:
#    user  system elapsed
#   0.238   0.000   0.238

# %%
fwrite(results %>% arrange(pval), paste0(UTIL_DIR, "zscores_tmp.csv"))

# %% [markdown]
# #### 2 - Relations with top Z-scores

# %% [markdown]
# - Linear model with proliferation

# %%
results <- fread(paste0(UTIL_DIR, "zscores_tmp.csv"))

# %%
top_zscores <- results %>% filter(grepl("zscore", x)) %>% arrange(pval) %>% head(20) %>% pull(x)

# %%
lms <- data.frame()
for(j in top_zscores){
  print(j); flush.console()
  for( i in features){
    lms <- rbind(lms, 
                 get_stats2( y = j, 
                 x = i, 
                 covariate = " + clin_primaryTumorLocation2 + clin_age + clin_sex", 
                 data = "df", 
                 model = "lm"))
}}
# Out:
# [1] "rna_mp_zscore_Malignant_MP26_NPC_Glioma"
# Warning message in model.matrix.default(mt, mf, contrasts):
# “the response appeared on the right-hand side and was dropped”
# Warning message in model.matrix.default(mt, mf, contrasts):
# “problem with term 1 in model.matrix: no columns are assigned”
# [1] "rna_mp_zscore_Fibroblast_Cell_cycle"
# Warning message in model.matrix.default(mt, mf, contrasts):
# “the response appeared on the right-hand side and was dropped”
# Warning message in model.matrix.default(mt, mf, contrasts):
# “problem with term 1 in model.matrix: no columns are assigned”
# [1] "rna_mp_zscore_Epithelial_EMT_like2"
# Warning message in model.matrix.default(mt, mf, contrasts):
# “the response appeared on the right-hand side and was dropped”
# Warning message in model.matrix.default(mt, mf, contrasts):
# “problem with term 1 in model.matrix: no columns are assigned”
# [1] "rna_mp_zscore_Fibroblast_Hypoxia"
# Warning message in model.matrix.default(mt, mf, contrasts):
# “the response appeared on the right-hand side and was dropped”
# Warning message in model.matrix.default(mt, mf, contrasts):
# “problem with term 1 in model.matrix: no columns are assigned”
# [1] "rna_mp_zscore_Lymphoid_CD8_Unassigned1"
# Warning message in model.matrix.default(mt, mf, contrasts):
# “the response appeared on the right-hand side and was dropped”
# Warning message in model.matrix.default(mt, mf, contrasts):
# “problem with term 1 in model.matrix: no columns are assigned”
# [1] "rna_mp_zscore_Macrophage_MAC2"
# Warning message in model.matrix.default(mt, mf, contrasts):
# “the response appeared on the right-hand side and was dropped”
# Warning message in model.matrix.default(mt, mf, contrasts):
# “problem with term 1 in model.matrix: no columns are assigned”
# [1] "rna_mp_zscore_Macrophage_Interferon"
# Warning message in model.matrix.default(mt, mf, contrasts):
# “the response appeared on the right-hand side and was dropped”
# Warning message in model.matrix.default(mt, mf, contrasts):
# “problem with term 1 in model.matrix: no columns are assigned”
# [1] "rna_mp_zscore_Lymphoid_CD4_Naive2"
# Warning message in model.matrix.default(mt, mf, contrasts):
# “the response appeared on the right-hand side and was dropped”
# Warning message in model.matrix.default(mt, mf, contrasts):
# “problem with term 1 in model.matrix: no columns are assigned”
# [1] "rna_mp_zscore_B_cell_B_cell_MHC_II"
# Warning message in model.matrix.default(mt, mf, contrasts):
# “the response appeared on the right-hand side and was dropped”
# Warning message in model.matrix.default(mt, mf, contrasts):
# “problem with term 1 in model.matrix: no columns are assigned”
# [1] "rna_mp_zscore_Malignant_MP3__Cell_Cylce_HMG_rich"
# Warning message in model.matrix.default(mt, mf, contrasts):
# “the response appeared on the right-hand side and was dropped”
# Warning message in model.matrix.default(mt, mf, contrasts):
# “problem with term 1 in model.matrix: no columns are assigned”
# [1] "rna_mp_zscore_Epithelial_Androgen_prostate"
# Warning message in model.matrix.default(mt, mf, contrasts):
# “the response appeared on the right-hand side and was dropped”
# Warning message in model.matrix.default(mt, mf, contrasts):
# “problem with term 1 in model.matrix: no columns are assigned”
# [1] "rna_mp_zscore_Epithelial_EpiSen"
# Warning message in model.matrix.default(mt, mf, contrasts):
# “the response appeared on the right-hand side and was dropped”
# Warning message in model.matrix.default(mt, mf, contrasts):
# “problem with term 1 in model.matrix: no columns are assigned”
# [1] "rna_mp_zscore_Endothelial_HEV1"
# Warning message in model.matrix.default(mt, mf, contrasts):
# “the response appeared on the right-hand side and was dropped”
# Warning message in model.matrix.default(mt, mf, contrasts):
# “problem with term 1 in model.matrix: no columns are assigned”
# [1] "rna_mp_zscore_Lymphoid_B_cell_Cell_cycle"
# Warning message in model.matrix.default(mt, mf, contrasts):
# “the response appeared on the right-hand side and was dropped”
# Warning message in model.matrix.default(mt, mf, contrasts):
# “problem with term 1 in model.matrix: no columns are assigned”
# [1] "rna_mp_zscore_Macrophage_MAC1"
# Warning message in model.matrix.default(mt, mf, contrasts):
# “the response appeared on the right-hand side and was dropped”
# Warning message in model.matrix.default(mt, mf, contrasts):
# “problem with term 1 in model.matrix: no columns are assigned”
# [1] "rna_mp_zscore_Malignant_MP36_IG"
# Warning message in model.matrix.default(mt, mf, contrasts):
# “the response appeared on the right-hand side and was dropped”
# Warning message in model.matrix.default(mt, mf, contrasts):
# “problem with term 1 in model.matrix: no columns are assigned”
# [1] "rna_mp_zscore_Malignant_MP15_EMT_IV"
# Warning message in model.matrix.default(mt, mf, contrasts):
# “the response appeared on the right-hand side and was dropped”
# Warning message in model.matrix.default(mt, mf, contrasts):
# “problem with term 1 in model.matrix: no columns are assigned”
# [1] "rna_mp_zscore_Malignant_MP35_Hemato_related_I"
# Warning message in model.matrix.default(mt, mf, contrasts):
# “the response appeared on the right-hand side and was dropped”
# Warning message in model.matrix.default(mt, mf, contrasts):
# “problem with term 1 in model.matrix: no columns are assigned”
# [1] "rna_mp_zscore_T_cell_CD8_Unassigned1"
# Warning message in model.matrix.default(mt, mf, contrasts):
# “the response appeared on the right-hand side and was dropped”
# Warning message in model.matrix.default(mt, mf, contrasts):
# “problem with term 1 in model.matrix: no columns are assigned”
# [1] "rna_mp_zscore_Fibroblast_CAF1"
# Warning message in model.matrix.default(mt, mf, contrasts):
# “the response appeared on the right-hand side and was dropped”
# Warning message in model.matrix.default(mt, mf, contrasts):
# “problem with term 1 in model.matrix: no columns are assigned”

# %%
lms <- lms %>% mutate(pval_by = p.adjust(pval, method = "BY"))

# %%
fwrite(lms, paste0(UTIL_DIR, "zscores_tmp2.csv"))
