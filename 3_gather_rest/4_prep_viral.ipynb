# %%
options(dplyr.summarise.inform = FALSE)
library(tidyverse)
library(data.table)

# %%
source(paste0(dirname(getwd()),'/map.r'))

# %% [markdown]
# #### 0 - Read collected Viral data

# %%
viral <- fread( paste0(TMP_DIR, "viral.csv") )

# %%
viral_reported <-
viral |>
  filter(reported) |>
  select(sampleId, interpretation, integrations) |>
  spread(interpretation, integrations)

# %%
viral_reported[is.na(viral_reported)] <- 0

# %%
colnames(viral_reported) <- c("sampleId", paste0("viral_", colnames(viral_reported)[-1]))

# %%
#viral_reported

# %% [markdown]
# #### 1 - Send it

# %%
fwrite(viral_reported, paste0(READY_DIR, "viral_ready.csv"))
