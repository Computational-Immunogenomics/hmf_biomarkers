# %%
options(dplyr.summarise.inform = FALSE)
library(tidyverse)
library(data.table)

# %%
source(paste0(dirname(getwd()),'/map.r'))

# %% [markdown]
# #### 0 - Read and process collected TEAL data

# %%
teal_ready <- 
fread( paste0(TMP_DIR, "teal.csv")) |>
  mutate(sampleId = gsub("R", "T", sampleId)) |> 
  select(sampleId, type, finalTelomereLength) |> 
  spread( type, finalTelomereLength) |>
  transmute( sampleId, 
            teal_ref = ref, 
            teal_tumor = ifelse(tumor <= 0, 0, tumor), 
            teal_ratio = log2(teal_tumor/teal_ref+1) )

# %% [markdown]
# #### 1 - Send it

# %%
fwrite(teal_ready, paste0(READY_DIR, "teal_ready.csv"))
