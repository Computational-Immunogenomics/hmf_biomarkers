# %%
library(tidyverse)
library(data.table)

# %%
#list.files("/mnt/bioinfnas/immunocomp/jusset/biomarkers/")
source("/mnt/bioinfnas/immunocomp/jusset/biomarkers/map.r")

# %%
LILAC_DIR = paste0(HMF_DATA, "lilac/lilac_out/")

# %%
test <- fread( paste0(LILAC_DIR, "ACTN01020003T.lilac.tsv"))
qc <- fread( paste0(LILAC_DIR, "ACTN01020003T.lilac.qc.tsv"))
#list.files(LILAC_DIR)

# %%
t(qc)
# Out:
#                             [,1]
# Status                      PASS
# ScoreMargin                 7.669
# NextSolutionAlleles         A*30:136
# MedianBaseQuality           37
# HlaYAllele                  Y*02:01
# DiscardedIndels             0
# DiscardedIndelMaxFrags      0
# DiscardedAlignmentFragments 55
# A_LowCoverageBases          0
# B_LowCoverageBases          0
# C_LowCoverageBases          0
# ATypes                      2
# BTypes                      2
# CTypes                      2
# TotalFragments              1821
# FittedFragments             1545
# UnmatchedFragments          36
# UninformativeFragments      9
# HlaYFragments               240
# PercentUnique               0.611
# PercentShared               0.389
# PercentWildcard             0
# UnusedAminoAcids            0
# UnusedAminoAcidMaxFrags     0
# UnusedHaplotypes            1
# UnusedHaplotypeMaxFrags     4
# SomaticVariantsMatched      0
# SomaticVariantsUnmatched    0
